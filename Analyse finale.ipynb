# %% [markdown]
# # Analyse des écoles et collèges français suite aux diverses polémiques sur le secteur privé et publique.
#
# Source des fichiers : data-gouv ministère de l'Éducation nationale

# %% [markdown]
# Objectif : voir les différences générales entre les établissements publics et privés en France.

# %%
# import des bibliotheques
# import bibliothéques d'analyse de python
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import numpy as np

import fonctions.perso_stats as perso_stats

# %%
# import des fichiers
ecole = pd.read_csv('donnee_temp/ecole.csv',low_memory=False)
                                                    
college = pd.read_csv('donnee_temp/college.csv',low_memory=False)

lycee = pd.read_csv('donnee_temp/lycee.csv',low_memory=False)

# %%
# style graphe :
sns.set_theme(style="whitegrid")
#plt.style.use("dark_background")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("pastel")
palette = sns.color_palette("pastel").as_hex()

# %% [markdown]
# # École maternelle et élémentaire :
# <br>
# On regarde la situation générale, et si on peut voir une discrimination des élèves en fonction de leur statut social.

# %%
fig,ax = plt.subplots()
sns.lineplot(data=ecole,x='Rentrée scolaire',y="Nombre total d'élèves",ax=ax,estimator='sum')
ax.set_ylim(0)
ax.ticklabel_format(axis='y',style='plain')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ",")))
ax.set_title("Nombre d'élèves total par an")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre total d'élèves")
plt.show()

# %% [markdown]
# Le nombre d'élèves est en légère baisse.

# %%
fig,ax = plt.subplots()
sns.lineplot(data=ecole,x='Rentrée scolaire',y="Nombre total d'élèves",hue="secteur",ax=ax,estimator='sum')
ax.set_ylim(0)
ax.ticklabel_format(axis='y',style='plain')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ",")))
ax.set_title("Nombre d'élève total par an")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre total d'élèves")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# La baisse est plus forte en public qu'en privé.

# %%
fig,ax = plt.subplots()
fig.set_size_inches(8,8)
sns.lineplot(data=ecole,x='Rentrée scolaire',y="Nombre moyen d'élève par classe",hue="secteur",ax=ax,estimator='mean')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_title("Nombre moyen d'élèves par classe entre 2019 et 2022")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre moyen d'élèves par classe")
ax.set_ylim()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Le nombre d'élèves par classe baisse globalement.<br>
# L'école publique à moins d'élèves par classe que les écoles privée.<br>
# Donc le professeur en public a plus de temps à consacrer à chaque élève que les professeurs dans le privé.<br>

# %%
fig,ax = plt.subplots()
sns.lineplot(data=ecole,x='Rentrée scolaire',y='Pourcentage ULIS',hue='secteur',ax=ax,estimator='mean')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_title("Pourcentage d´élèves Ulis moyen entre 2019 et 2022",pad=15)
ax.set_xlabel("Année")
ax.set_ylabel("Pourcentage d'élèves Ulis")
ax.set_ylim(0)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# On a environ 2 fois moins d´élèves ULIS dans les classes des écoles privées.

# %%
fig,ax = plt.subplots()
sns.barplot(data=ecole[ecole['Rentrée scolaire']>2021],x='Rentrée scolaire', y="IPS",hue='secteur',ax=ax,estimator="mean",errorbar=None)
ax.set_title("Indice de Position Sociale moyen en 2022",pad=15)
ax.set_ylabel("Valeur IPS")
ax.bar_label(ax.containers[0], fontsize=10)
ax.bar_label(ax.containers[1], fontsize=10)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_ylim(0)
plt.show()

# %% [markdown]
# Les conditions sociales des élèves du privé sont plus favorables à la réussite que dans le public.<br>

# %% [markdown]
# ### Conclusion école :
# <br>
# Les écoles privées ont en moyenne plus d'élèves dans leurs classes que les établissements publics.<br>
# Certaines personnes y voient un raisonnement économique : plus d'élèves par classes plus de profit.<br>
# D'autres personnes y voient une autre raison : plus il y a d'élèves en classe, plus il y a d'émulsion.<br>
# Certains témoignages parlent plus de réseautages. Ces établissements seraient plus là pour acquérir des relations que pour acquérir des savoirs.<br>
# <br>
# Les écoles publiques ont en moyenne plus d'élèves du type ULIS que les ceux du privé. De plus, les élèves du privé sont issus d'un milieu plus favorable.<br>
# N'ayant pas de plus amples détails sur l'IPS dans les écoles primaires et maternelles, je ne peux pas confirmer ou non les discours politiques qui disent qu'il y a une sectorisation des élèves. Les pauvres restants dans le public, les riches dans le privé.<br>

# %% [markdown]
# # Collège

# %%
fig,ax = plt.subplots()
sns.lineplot(data=college,x='Rentrée scolaire',y="Nombre d'élèves total",ax=ax,estimator='sum')
ax.set_ylim(0)
ax.ticklabel_format(axis='y',style='plain')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ",")))
ax.set_title("Nombre de collégiens total par an")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre total d'élèves")
plt.show()

# %% [markdown]
# Le nombre de collégiens reste stable.

# %%
fig,ax = plt.subplots()
sns.lineplot(data=college,x='Rentrée scolaire',y="Nombre d'élèves total",ax=ax,estimator='sum',hue='Secteur')
ax.set_ylim(0)
ax.ticklabel_format(axis='y',style='plain')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ",")))
ax.set_title("Nombre de collégiens total par an")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre total d'élèves")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Le nombre d'élèves dans le privé reste très stable.<br>
# Le nombre d'élèves dans le public subit un peu plus de fluctuation, mais très légère.<br>

# %%
fig,ax = plt.subplots()
sns.lineplot(data=college,x='Rentrée scolaire',y="Pourcentage Ulis sur le nombre d'eleves total",hue='Secteur',ax=ax)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_title("Pourcentage de collégien Ulis en France entre 2019 et 2022",pad=15)
ax.set_xlabel("Année")
ax.set_ylabel("Poucentage collégien Ulis")
ax.set_ylim(0)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Le pourcentage d'élèves ULIS dans les classes est supérieur dans le public.<br>
# Il y a une augmentation constante des élèves ULIS dans le public. <br>
# L'augmentation en pourcentage était très forte en 2019 pour finalement se stabiliser en 2021 sur le privé.<br>

# %%
fig,ax = plt.subplots()
sns.barplot(data=college, y="IPS",ax=ax,estimator="mean",x='Secteur',errorbar=None)
ax.set_title("Indice de Position Sociale moyen en 2022",pad=15)
ax.set_ylabel("Valeur IPS")
ax.bar_label(ax.containers[0], fontsize=10)
ax.set_ylim(0)
plt.show()

# %% [markdown]
# L'écart moyen de l'indice de Position Sociale dans les collèges est plus important que dans les écoles primaires et maternelles.

# %%
fig,ax = plt.subplots()
sns.barplot(data=college[college["Rentrée scolaire"]>2020], x="Rentrée scolaire", y="Taux de réussite - G",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
ax.set_title("Taux d'obtention du brevet entre 2019 et 2022",pad=15)
ax.set_ylabel("Taux d'obtention en %")
ax.set_xlabel("Année")
ax.bar_label(ax.containers[0], fontsize=10)
ax.bar_label(ax.containers[1], fontsize=10)
ax.set_ylim(0)
ax.set_xlim()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Un écart de 10 points entre les résultats des collèges privés et publics.

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=college,y="Note à l'écrit - G",x='IPS',hue='Secteur',ax=ax)
ax.set_title('Indice de position sociale et résultats')
ax.set_ylabel('Moyenne génèrale du brevet')
ax.set_xlabel('Indice de Position Sociale')
ax.set_ylim(0,20)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
# verifier corrélation entre note et ips
corrélation_note_ips = round(college['IPS'].corr(college["Note à l'écrit - G"])*100,2)
print("On a une corrélation de ",corrélation_note_ips,"%.")
# Out:
# On a une corrélation de  79.55 %.

# %% [markdown]
# On remarque bien la corrélation entre l'IPS et les notes aux brevets.<br>
# L'IPS explique à 80 % les notes à l'écrit au brevet.<br>

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,10)
sns.scatterplot(data=college,x="Taux d'accès 6ème-3ème" ,y='Taux de réussite - G',hue='Secteur',ax=ax)
ax.set_title('Taux de réussite et suivie du collège')
ax.set_ylabel('Taux de réussite du brevet')
ax.set_xlabel("Pourcentage d'élève restant dans l'établissement de la 6ieme à la 3ieme")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Le taux de réussite au brevet est plus haut dans le privé, mais le taux de maintien des élèves dans les établissements publics est plus haut.

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=college,x='IPS',y="Ecart-type de l'IPS",hue='Secteur',ax=ax)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_ylabel("Écart-type de l'IPS")
ax.set_title("Analyse de l'IPS des collèges")
plt.show()

# %% [markdown]
# Comparaison des populations des collèges privés et publics au niveau de l'IPS :

# %%
pop_public = college[college['Secteur']=='PUBLIC']
pop_privé =  college[college['Secteur']=='PRIVE']
result = perso_stats.ANOVA(df1=pop_public['IPS'].dropna(),df2=pop_privé['IPS'].dropna())

del pop_privé,pop_public
# Out:
# Interprétation du test:
# H0 : Les moyennes des groupes sont égales
# H1 : Les moyennes des groupes ne sont pas égales
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  0.0 %

# %% [markdown]
# On s'aperçoit qu'au niveau de l'IPS, certains collèges privés ont une population plutôt privilégiée.<br>
# Certains collèges ont donc un IPS très élevé avec un faible écart type ce qui peut être aperçu comme un entre-soi.<br>
# Á l'autre extrémité certains collèges publics ont un public avec un faible IPS et une faible mixité sociale.<br>
# Cela peut ressembler de loin à une sorte de ghettoïsation d'une certaine population.<br>

# %%
fig,ax = plt.subplots()
sns.boxplot(data=college[college["Rentrée scolaire"]>2020], x="Rentrée scolaire", y="VA de la note - G",ax=ax)
ax.set_title("Valeur ajoutée des notes à l'écrit en 2022 ",pad=15)
ax.set_ylabel("Valeur ajoutée des colléges")
ax.set_xlabel("Année")
plt.show()

# %% [markdown]
# Une moyenne a 0.

# %%
fig,ax = plt.subplots()
sns.boxplot(data=college[college["Rentrée scolaire"]>2020], x="Rentrée scolaire", y="VA de la note - G",ax=ax,hue="Secteur")
ax.set_title("Valeur ajoutée des notes à l'écrit à partir de 2021",pad=15)
ax.set_ylabel("Valeur ajoutée des colléges")
ax.set_xlabel("Année")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
# prepa donnée : les données ayant pas de resultats autre que 2022 + college sans donnée
college2022 = college[college['Rentrée scolaire']==2022].copy()

# distributon va de la note
fig,ax =plt.subplots()
sns.histplot(college2022,x='VA de la note - G',ax=ax)
ax.set_title('distribution de la valeur ajoutée')
plt.show()
del fig,ax
# test normalité valeur ajouté
print("Test de shapiro pour voir si la distribution suis une normale")
rep = perso_stats.test_loi_normale(college2022['VA de la note - G'])
del rep
# Out:
# Test de shapiro pour voir si la distribution suis une normale
#
#
# Interprétation du test:
# H0 : La série suit une loi Normale
# H1 : La série ne suit pas une loi Normale
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  nan %

# %% [markdown]
# Dans la notice :<br>
# En moyenne, la réussite des élèves comparables en termes sociodémographiques et scolaires est très sensible à la composition sociodémographique des collèges où ils sont scolarisés (âge, origine sociale, niveau scolaire à l’entrée en sixième et sexe des élèves).<br>
# <br>
# Le calcul de la valeur ajoutée prend en compte ces critères selon la notice.<br>
# Mais j'ai un doute car :
# <ul>
# <li>80 % de la note est corrélée par l'IPS.</li>
# <li>Les populations des établissement privés et publics ne sont pas les mêmes en termes sociaux</li>
# <li>En moyenne, les établissements privés ressortent positivement. (ils ajoutent de la valeur ajoutée)</li>
# </ul>
# N'ayant pas accès aux calculs exacts de cette valeur ajoutée, je doute de la validité et de l'impartialité de cet indicateur.<br>
# De plus, le calcul est basé sur une prédiction, donc déjà la prédiction est elle exacte? <br>
# Cet indicateur va être souvent utilisé par les médias pour faire un classement des établissements. Les médias vont juste donner le classement sans analyser l'indicateur.<br>
# La valeur ajoutée n'est pas distribuée normalement. Ce qui me met un doute supplémentaire sur la viabilité de leur prévision.<br>
# Les analystes qui ont créé cet indicateur ont certainement fait un gros travail, mais je pense qu'il reste encore du travail à fournir pour avoir un vrai indicateur de la "valeur ajoutée" des établissements.<br>
# Une tentative de recréer la "valeur ajoutée des notes" est faite dans le notebook "test de prédiction des notes du brevet.ipynb"<br>
# <br>
# Pour plus de renseignements sur la Valeur ajouté, vous pouvez télécharger la dernière notice <a href =https://www.data.gouv.fr/fr/datasets/indicateurs-de-valeur-ajoutee-des-colleges/>ici</a>

# %% [markdown]
# Conclusion collège :<br>
# Les écarts sociaux se creusent au niveau du collège.<br>
# On remarque un commencement de création de "clan scolaire" par rapport aux origines sociales des individus.<br>
# Les résultats aux brevets sont majoritairement dus à l'origine sociale des parents.<br>
# Pour améliorer les résultats sur le long terme, il faudrait améliorer les conditions sociales des parents.<br>

# %% [markdown]
# # Lycée

# %% [markdown]
# Observons la situation dans les lycées de France.

# %%
# type de lycee ips et rentree :
fig,ax = plt.subplots()
sns.boxplot(data=lycee[lycee['Rentrée scolaire']==2022],x='Type de lycée', y='IPS Ensemble GT-PRO',ax=ax)
ax.set_title('IPS en fonction du type de lycée en 2022',pad=30)
ax.set_ylabel("IPS moyen")
plt.show()

# %%
# type de lycee ips et rentree :
fig,ax = plt.subplots()
sns.boxplot(data=lycee[lycee['Rentrée scolaire']==2022],x='Type de lycée', y='IPS Ensemble GT-PRO',hue='Secteur',ax=ax)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_title('IPS en fonction du type de lycée en 2022',pad=30)
ax.set_ylabel("IPS moyen")
plt.show()

# %% [markdown]
# Sans surprise, le secteur public a une population avec un IPS plus bas que le privé.<br>
# Les établissements d'enseignement général ont un indice plus haut que les établissements Professionnel et Technique.<br>

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=lycee,x='IPS voie GT',y="Ecart-type de l'IPS voie GT",hue='Secteur',ax=ax)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_ylabel("écart type de l'IPS")
ax.set_title("Analyse de l'IPS des lycées généraux")
plt.show()

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=lycee,x='IPS voie PRO',y="Ecart-type de l'IPS voie PRO",hue='Secteur',ax=ax)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_ylabel("écart type de l'IPS")
ax.set_title("Analyse de l'IPS des lycées pro")
plt.show()

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=lycee,x='IPS voie PRO',y="Ecart-type de l'IPS voie PRO",ax=ax,label='Cursus Professionnel',color=palette[3])
sns.scatterplot(data=lycee,x='IPS voie GT',y="Ecart-type de l'IPS voie GT",ax=ax,label='Cursus Général et Technique',color=palette[9])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.set_ylabel("écart type de l'IPS")
ax.set_title("Analyse de l'IPS des lycées")
plt.show()

# %% [markdown]
# On s'aperçoit que le cursus professionnel a pas mal de lycée dont l'IPS est bas avec un écart-type faible.<br>
# Cela ressemble à une "ghetorisation" de certains lycées.<br>
# Une grande majorité des établissements ont un IPS entre 85 et 135 avec un bon écart type ce qui favorise la mixité sociale.<br>
# Mais une forme "d'élitisation" à l'air d'apparaître dans les IPS plus élevé. (IPS > 140 et écart type faible).<br>
# Bizarrement, il n'y a pas de cursus professionnels au-dessus de 130 d'IPS.<br>

# %%
fig,ax = plt.subplots()
fig.set_size_inches(15,10)
sns.barplot(data=lycee, x='Type de diplome gen pro', y="Taux de reussite",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
#mettre les labels a 90 degres
ax.set_xlabel("Type de diplome")
ax.set_title("Taux de réussite en fonction du secteur et du type du cursus")
ax.set_ylabel("Taux de réussite")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Les diplômes orientés professionnel ont un taux de réussite moins élevé que les diplômes généraux.<br>
# On a plus de chance d'avoir son diplôme dans une école privée.

# %%
fig,ax = plt.subplots()
fig.set_size_inches(7,7)
sns.barplot(data=lycee, x='Type de lycée', y="IPS voie GT",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
#mettre les labels a 90 degres
ax.set_xlabel("Type de diplome")
ax.set_title("IPS en fonction du type de lycée et du secteur en filière générale")
ax.set_ylabel("IPS")
ax.tick_params(axis='x', labelrotation=90)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
fig,ax = plt.subplots()
fig.set_size_inches(7,7)
sns.barplot(data=lycee, x='Type de lycée', y="IPS voie PRO",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
#mettre les labels a 90 degres
ax.set_xlabel("Type de diplome")
ax.set_title("IPS  en fonction du type de lycée et du secteur en filière professionnelle")
ax.set_ylabel("IPS")
ax.tick_params(axis='x', labelrotation=90)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# L'IPS peut expliquer l'écart de réussite entre les secteurs, mais aussi entre les filières générales et professionnelles.<br>
# Cela impliquerait que le cursus général et professionnel sont aussi exigent l'un que l'autre.

# %%
# diplome et resultats :
fig,ax = plt.subplots()
fig.set_size_inches(15,10)
sns.barplot(data=lycee, x="Serie", y="Taux de reussite",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
ax.set_xlabel("Serie")
ax.set_title("Taux de résussite en fonction des séries et du secteur du lycée")
ax.set_ylabel("Taux de réussite")
ax.tick_params(axis='x', labelrotation=90)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Les bacs généraux S,ES et L n'existent plus depuis 2020. Les nouveaux bacs sont plus ou moins durs en fonction de la série. (STG et STI ont un taux de réussite inférieur que les 3 anciens).<br>
# Les bacs professionnels ont un taux de réussite moins élevé que leur homologue du général notamment ceux orientés en industrie.

# %%
# diplome et resultats :
fig,ax = plt.subplots()
fig.set_size_inches(15,10)
sns.barplot(data=lycee, x="Serie", y="Taux de mentions",ax=ax,hue="Secteur",estimator="mean",errorbar=None)
ax.tick_params(axis='x', labelrotation=90)
ax.set_xlabel("Serie")
ax.set_title("Taux de mention en fonction des séries et du secteur de lycée")
ax.set_ylabel("Taux de mention")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
# diplome et resultats :
fig,ax = plt.subplots()
fig.set_size_inches(15,10)
sns.barplot(data=lycee, x="Serie", y="Valeur ajoutee du taux de reussite",ax=ax,hue="Type de lycée",estimator="mean",errorbar=None)
ax.tick_params(axis='x', labelrotation=90)
ax.set_xlabel("Serie")
ax.set_title(" Valeur ajoutee du taux de reussite en fonction des séries et du type de lycée")
ax.set_ylabel("Valeur ajoutee du taux de reussite")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
# diplome et resultats :
fig,ax = plt.subplots()
fig.set_size_inches(15,10)
sns.barplot(data=lycee, x="Serie", y="Valeur ajoutee du taux de mentions",ax=ax,hue="Type de lycée",estimator="mean",errorbar=None)
ax.tick_params(axis='x', labelrotation=90)
ax.set_xlabel("Serie")
ax.set_title(" Valeur ajoutee du taux de mentions en fonction des séries et du type de lycée")
ax.set_ylabel("Valeur ajoutee du taux de mentions")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# En conclusion :<br>
# <br>
# Les écoles privées ont de meilleurs résultats grâce à leur public plus privilégié.<br>
# Il y a un effet de groupe qui classe les élèves en fonction de leur niveau social.<br>
# Cette séparation est déjà présente au collège, mais des barrières au niveau du cursus se dresse à partir du lycée.(partir en école supérieure avec un diplôme professionnel est souvent très difficile.).<br>
# Il y a donc déjà les fameux groupes de niveau qui se crée naturellement par la géographie et l'IPS.<br>
# En effet, il y a peu d'écart-types dans les niveaux d'IPS fort et faible. <br>
# L'IPS explique en grande partie les résultats scolaires.<br>
# <br>
# Pour améliorer le niveau scolaire, il faut que l'école ait beaucoup plus de moyens pour contrecarrer le niveau social ou bien améliorer l'IPS.<br>
# Donc il faudrait améliorer la situation sociale des parents.<br>
# <br>
# Pour l'instant l'école à l'air juste de maintenir le niveau social de la population.<br>
# Les parents avec un faible IPS mettent leur enfant dans des établissements à faible IPS, et leur enfant passe un diplôme professionnel qui ne lui permet pas d'augmenter son IPS par rapport à celui de ses parents. <br>
